# %%
# !pip install pyttsx3
import pyttsx3
engine = pyttsx3.init()
engine.say('Sally sells seashells by the seashore.')
engine.runAndWait()
# Out:
# ...
#   Obtaining dependency information for comtypes from https://files.pythonhosted.org/packages/7e/f1/759a8c4d58695b9fcc2e22b0c986447759534084ddd6c4ad53df07c6fdfa/comtypes-1.3.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/194.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/194.1 kB ? eta -:--:--
#    ---------------- ----------------------- 81.9/194.1 kB 1.1 MB/s eta 0:00:01
#    ------------------ -------------------- 92.2/194.1 kB 744.7 kB/s eta 0:00:01
#    ------------------------ ------------- 122.9/194.1 kB 722.1 kB/s eta 0:00:01
#    ---------------------------- --------- 143.4/194.1 kB 655.8 kB/s eta 0:00:01
#    -------------------------------- ----- 163.8/194.1 kB 614.4 kB/s eta 0:00:01
#    ---------------------------------- --- 174.1/194.1 kB 523.5 kB/s eta 0:00:01
#    ------------------------------------ - 184.3/194.1 kB 483.6 kB/s eta 0:00:01
# ...

# %%
engine = pyttsx3.init()
engine.say("WHO defines Quality of Life as an individual's perception of their position in life in the context of the culture and value systems in which they live and in relation to their goals, expectations, standards and concerns.")
engine.runAndWait()

# %%
<Queue> = queue.Queue(maxsize=0)               # A thread-safe first-in-first-out queue.
<Queue>.put(<el>)                              # Blocks until queue stops being full.
<Queue>.put_nowait(<el>)                       # Raises queue.Full exception if full.
<el> = <Queue>.get()                           # Blocks until queue stops being empty.
<el> = <Queue>.get_nowait()                    # Raises queue.Empty exception if empty.
# Out:
#   Cell In[8], line 1
#     <Queue> = queue.Queue(maxsize=0)               # A thread-safe first-in-first-out queue.
#     ^
# SyntaxError: invalid syntax

# %%
for i in range(7):
    for j in range(5):
        if ((j==0 or j==4) and i !=0) or ((i==0 or i==3) and (j>0 and j<4)):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
for i in range(7):
    for j in range(5):
        if (j==0 or ( j==4 and (i!=0 and i!=3 and i!=6)) or ((i==0 or i==3 or i==6) and (j>0 and j<4))):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# ****

# %%
for i in range(7):
    for j in range(5):
        if (j==0 and (i!=0 and i!=6))  or ((i==0 or i==6) and (j>0)):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
#  ****
# *
# *
# *
# *
# *
#  ****

# %%
for i in range(7):
    for j in range(5):
        if (j==0) or (j==4 and (i!=0 and i!=6)) or ((i==0 or i==6) and (j>0 and j<4)):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
# ****
# *   *
# *   *
# *   *
# *   *
# *   *
# ****

# %%
for i in range(7):
    for j in range(5):
        if (j==0) or ((i==0 or i==3 or i==6) and (j>0 and j<4)):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
# ****
# *
# *
# ****
# *
# *
# ****

# %%
for i in range(7):
    for j in range(5):
        if (j==0) or ((i==0 or i==3 ) and (j>0 and j<4)):
            print('*',end='')
        else:
            print(end=' ')
    print()
# Out:
# ****
# *
# *
# ****
# *
# *
# *

# %%
for i in range(7):
    for j in range(5):
        if (j==0) or ((i==0 or i==3 ) and (j>0 and j<4)):
            print('*',end='')
        else:
            print(end=' ')
    print()

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 import numpy as np
#       2 import random
# ----> 3 random.random(1,10)
#
# TypeError: Random.random() takes no arguments (2 given)

# %%
data = {i: list(np.random.random(8))  for i in range(1,101)}
data
# Out:
# {1: [0.9679401320703106,
#   0.684016272702726,
#   0.059966641514872965,
#   0.07029117499363546,
#   0.7926178284609523,
#   0.0011381987710049613,
#   0.9637465846073825,
#   0.2299142588729115],
#  2: [0.41940751487235695,
#   0.4082578249436074,
#   0.3680445904457518,
#   0.7563161250179603,
#   0.9625615622057049,
#   0.21069037211115205,
#   0.5702441698698151,
#   0.5602339352152832],
#  3: [0.02540564207394458,
#   0.41940533836984817,
#   0.8413699745496916,
#   0.6513871923319035,
#   0.8222889204706592,
#   0.20843064985044724,
#   0.5556101689820819,
#   0.8592893795770882],
#  4: [0.12965548539070304,
#   0.911192064990247,
#   0.07448439290894204,
#   0.3619106765525367,
#   0.5881391007559307,
#   0.568915629251904,
#   0.3403292141136598,
#   0.24706820859002965],
#  5: [0.5530284429266275,
#   0.8185556797102254,
#   0.940389080131669,
#   0.7521882311001433,
#   0.28668003433553446,
#   0.8264408595169443,
#   0.8451516509838243,
#   0.05554848830592907],
# ...

# %%
# Out:
# array([0.96314599, 0.49288267, 0.88706226, 0.88115355, 0.32833998,
#        0.27014952, 0.59679571, 0.81574595])
